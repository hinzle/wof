# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(0, '/Users/hinzlehome/codeup-data-science/clustering-exercises/')

from utils.imports import *

# %% [markdown]
# # acquire.py

# %%
def acquire():
    '''
    Acquires zillow data from mySQL using the python module to connect and query. 
    Outputs a single dataframe. 
    Include's the logerror.
    Uses all the tables in the database and all fields related to the properties that are available.
    Only includes properties with a transaction in 2017, and only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction.
    Only includes properties that include a latitude and longitude value.
    Code by: Zach Gulde (https://github.com/CodeupClassroom/innis-clustering-exercises)
    '''

    query = '''
    SELECT
        prop.*,
        predictions_2017.logerror,
        predictions_2017.transactiondate,
        air.airconditioningdesc,
        arch.architecturalstyledesc,
        build.buildingclassdesc,
        heat.heatingorsystemdesc,
        landuse.propertylandusedesc,
        story.storydesc,
        construct.typeconstructiondesc
    FROM properties_2017 prop
    JOIN (
        SELECT parcelid, MAX(transactiondate) AS max_transactiondate
        FROM predictions_2017
        GROUP BY parcelid
    ) pred USING(parcelid)
    JOIN predictions_2017 ON pred.parcelid = predictions_2017.parcelid
                        AND pred.max_transactiondate = predictions_2017.transactiondate
    LEFT JOIN airconditioningtype air USING (airconditioningtypeid)
    LEFT JOIN architecturalstyletype arch USING (architecturalstyletypeid)
    LEFT JOIN buildingclasstype build USING (buildingclasstypeid)
    LEFT JOIN heatingorsystemtype heat USING (heatingorsystemtypeid)
    LEFT JOIN propertylandusetype landuse USING (propertylandusetypeid)
    LEFT JOIN storytype story USING (storytypeid)
    LEFT JOIN typeconstructiontype construct USING (typeconstructiontypeid)
    WHERE prop.latitude IS NOT NULL
    AND prop.longitude IS NOT NULL
    AND transactiondate <= '2017-12-31'
    '''
    
    if os.path.exists('/Users/hinzlehome/codeup-data-science/clustering-exercises/csvs/zillow.csv'):
        df = pd.read_csv('/Users/hinzlehome/codeup-data-science/clustering-exercises/csvs/zillow.csv')
    else:
        url=get_db_url('zillow')
        df = pd.read_sql(query, url)
        df.to_csv('/Users/hinzlehome/codeup-data-science/clustering-exercises/csvs/zillow.csv', index=False)
    return df

# %%
def overview(df):
    print('--- Shape: {}'.format(df.shape))
    print('--- Info')
    df.info()
    print('--- Column Descriptions')
    print(df.describe(include='all'))

# %%
def nulls_by_columns(df):
    return pd.concat([
        df.isna().sum().rename('count'),
        df.isna().mean().rename('percent')
    ], axis=1)

# %%
def nulls_by_rows(df):
    return pd.concat([
        df.isna().sum(axis=1).rename('n_missing'),
        df.isna().mean(axis=1).rename('percent_missing'),
    ], axis=1).value_counts().sort_index()

# %%
def acquire_show():
    df=acquire()
    overview(df)
    nulls_by_columns(df)
    nulls_by_rows(df)
    return df

# %%
# df=acquire()

# %%
# overview(df)

# %%
# nulls_by_columns(df)

# %%
# nulls_by_rows(df)

# %%
df=acquire_show()
# Out:
# /var/folders/mk/w2hz4wxx7xn5hr_56wz536gh0000gn/T/ipykernel_2201/3830353953.py:2: DtypeWarning: Columns (63) have mixed types.Specify dtype option on import or set low_memory=False.
#   df=acquire()
# --- Shape: (77380, 68)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77380 entries, 0 to 77379
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            77380 non-null  int64
#  1   parcelid                      77380 non-null  int64
#  2   airconditioningtypeid         24953 non-null  float64
#  3   architecturalstyletypeid      206 non-null    float64
#  4   basementsqft                  50 non-null     float64
#  5   bathroomcnt                   77380 non-null  float64
#  6   bedroomcnt                    77380 non-null  float64
#  7   buildingclasstypeid           15 non-null     float64
#  8   buildingqualitytypeid         49671 non-null  float64
#  9   calculatedbathnbr             76771 non-null  float64
#  10  decktypeid                    614 non-null    float64
#  11  finishedfloor1squarefeet      6023 non-null   float64
#  12  calculatedfinishedsquarefeet  77184 non-null  float64
#  13  finishedsquarefeet12          73748 non-null  float64
#  14  finishedsquarefeet13          41 non-null     float64
#  15  finishedsquarefeet15          3009 non-null   float64
#  16  finishedsquarefeet50          6023 non-null   float64
#  17  finishedsquarefeet6           386 non-null    float64
#  18  fips                          77380 non-null  float64
#  19  fireplacecnt                  8276 non-null   float64
#  20  fullbathcnt                   76771 non-null  float64
#  21  garagecarcnt                  25474 non-null  float64
#  22  garagetotalsqft               25474 non-null  float64
#  23  hashottuborspa                1538 non-null   float64
#  24  heatingorsystemtypeid         49439 non-null  float64
#  25  latitude                      77380 non-null  float64
#  26  longitude                     77380 non-null  float64
#  27  lotsizesquarefeet             69141 non-null  float64
#  28  poolcnt                       16137 non-null  float64
#  29  poolsizesum                   867 non-null    float64
#  30  pooltypeid10                  464 non-null    float64
#  31  pooltypeid2                   1074 non-null   float64
#  32  pooltypeid7                   15042 non-null  float64
#  33  propertycountylandusecode     77380 non-null  object
#  34  propertylandusetypeid         77380 non-null  float64
#  35  propertyzoningdesc            50330 non-null  object
#  36  rawcensustractandblock        77380 non-null  float64
#  37  regionidcity                  75909 non-null  float64
#  38  regionidcounty                77380 non-null  float64
#  39  regionidneighborhood          30890 non-null  float64
#  40  regionidzip                   77330 non-null  float64
#  41  roomcnt                       77380 non-null  float64
#  42  storytypeid                   50 non-null     float64
#  43  threequarterbathnbr           10096 non-null  float64
#  44  typeconstructiontypeid        222 non-null    float64
#  45  unitcnt                       50562 non-null  float64
#  46  yardbuildingsqft17            2388 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77117 non-null  float64
#  49  numberofstories               17560 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77268 non-null  float64
#  52  taxvaluedollarcnt             77379 non-null  float64
#  53  assessmentyear                77380 non-null  float64
#  54  landtaxvaluedollarcnt         77378 non-null  float64
#  55  taxamount                     77375 non-null  float64
#  56  taxdelinquencyflag            2886 non-null   object
#  57  taxdelinquencyyear            2886 non-null   float64
#  58  censustractandblock           77136 non-null  float64
#  59  logerror                      77380 non-null  float64
#  60  transactiondate               77380 non-null  object
#  61  airconditioningdesc           24953 non-null  object
#  62  architecturalstyledesc        206 non-null    object
#  63  buildingclassdesc             15 non-null     object
#  64  heatingorsystemdesc           49439 non-null  object
#  65  propertylandusedesc           77380 non-null  object
#  66  storydesc                     50 non-null     object
#  67  typeconstructiondesc          222 non-null    object
# dtypes: float64(55), int64(2), object(11)
# memory usage: 40.1+ MB
# --- Column Descriptions
#                   id      parcelid  airconditioningtypeid  \
# count   7.738000e+04  7.738000e+04           24953.000000
# unique           NaN           NaN                    NaN
# top              NaN           NaN                    NaN
# freq             NaN           NaN                    NaN
# mean    1.495126e+06  1.300715e+07               1.813289
# std     8.609057e+05  3.481368e+06               2.967894
# min     3.490000e+02  1.071186e+07               1.000000
# 25%     7.520500e+05  1.153830e+07               1.000000
# 50%     1.497870e+06  1.253155e+07               1.000000
# 75%     2.240480e+06  1.421184e+07               1.000000
# max     2.982274e+06  1.676893e+08              13.000000
#
#         architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                 206.000000     50.000000  77380.000000  77380.000000
# unique                       NaN           NaN           NaN           NaN
# top                          NaN           NaN           NaN           NaN
# freq                         NaN           NaN           NaN           NaN
# mean                    7.388350    679.720000      2.299134      3.053489
# std                     2.734542    689.703546      0.996657      1.139103
# min                     2.000000     38.000000      0.000000      0.000000
# 25%                     7.000000    273.000000      2.000000      2.000000
# 50%                     7.000000    515.000000      2.000000      3.000000
# 75%                     7.000000    796.500000      3.000000      4.000000
# max                    21.000000   3560.000000     18.000000     16.000000
#
#         buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# count             15.000000           49671.000000       76771.000000
# unique                  NaN                    NaN                NaN
# top                     NaN                    NaN                NaN
# freq                    NaN                    NaN                NaN
# mean               3.933333               6.534638           2.316871
# std                0.258199               1.721933           0.979761
# min                3.000000               1.000000           1.000000
# 25%                4.000000               6.000000           2.000000
# 50%                4.000000               6.000000           2.000000
# 75%                4.000000               8.000000           3.000000
# max                4.000000              12.000000          18.000000
#
#         decktypeid  finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# count        614.0               6023.000000                  77184.000000
# unique         NaN                       NaN                           NaN
# top            NaN                       NaN                           NaN
# freq           NaN                       NaN                           NaN
# mean          66.0               1366.512535                   1785.229465
# std            0.0                671.308125                    954.051796
# min           66.0                 44.000000                    128.000000
# 25%           66.0                955.000000                   1182.000000
# 50%           66.0               1257.000000                   1543.000000
# 75%           66.0               1615.000000                   2113.000000
# max           66.0               6912.000000                  35640.000000
#
#         finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# count           73748.000000             41.000000           3009.000000
# unique                   NaN                   NaN                   NaN
# top                      NaN                   NaN                   NaN
# freq                     NaN                   NaN                   NaN
# mean             1760.532177           1389.853659           2357.791625
# std               934.027008            123.531688           1188.775210
# min               128.000000           1056.000000            598.000000
# 25%              1172.000000           1344.000000           1625.000000
# 50%              1523.000000           1440.000000           2094.000000
# 75%              2076.000000           1440.000000           2838.000000
# max             21929.000000           1560.000000          35640.000000
#
#         finishedsquarefeet50  finishedsquarefeet6          fips  fireplacecnt  \
# count            6023.000000           386.000000  77380.000000   8276.000000
# unique                   NaN                  NaN           NaN           NaN
# top                      NaN                  NaN           NaN           NaN
# freq                     NaN                  NaN           NaN           NaN
# mean             1381.771542          2082.500000   6048.819385      1.191155
# std               726.468878          1240.382784     20.748290      0.491080
# min                44.000000           380.000000   6037.000000      1.000000
# 25%               956.000000           993.750000   6037.000000      1.000000
# 50%              1259.000000          1812.500000   6037.000000      1.000000
# 75%              1621.500000          3053.500000   6059.000000      1.000000
# max             12467.000000          5598.000000   6111.000000      5.000000
#
#          fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# count   76771.000000  25474.000000     25474.000000          1538.0
# unique           NaN           NaN              NaN             NaN
# top              NaN           NaN              NaN             NaN
# freq             NaN           NaN              NaN             NaN
# mean        2.250485      1.815459       350.111957             1.0
# std         0.966558      0.588345       261.681641             0.0
# min         1.000000      0.000000         0.000000             1.0
# 25%         2.000000      2.000000         0.000000             1.0
# 50%         2.000000      2.000000       436.000000             1.0
# 75%         3.000000      2.000000       493.000000             1.0
# max        18.000000     14.000000      4251.000000             1.0
#
#         heatingorsystemtypeid      latitude     longitude  lotsizesquarefeet  \
# count            49439.000000  7.738000e+04  7.738000e+04       6.914100e+04
# unique                    NaN           NaN           NaN                NaN
# top                       NaN           NaN           NaN                NaN
# freq                      NaN           NaN           NaN                NaN
# mean                 3.920447  3.400837e+07 -1.182036e+08       2.996963e+04
# std                  3.592789  2.653905e+05  3.594833e+05       1.233719e+05
# min                  1.000000  3.333953e+07 -1.194754e+08       2.360000e+02
# 25%                  2.000000  3.381457e+07 -1.184153e+08       5.700000e+03
# 50%                  2.000000  3.402200e+07 -1.181808e+08       7.206000e+03
# 75%                  7.000000  3.417439e+07 -1.179284e+08       1.183100e+04
# max                 24.000000  3.481877e+07 -1.175546e+08       6.971010e+06
#
#         poolcnt  poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# count   16137.0   867.000000         464.0       1074.0      15042.0
# unique      NaN          NaN           NaN          NaN          NaN
# top         NaN          NaN           NaN          NaN          NaN
# freq        NaN          NaN           NaN          NaN          NaN
# mean        1.0   517.916955           1.0          1.0          1.0
# std         0.0   156.716017           0.0          0.0          0.0
# min         1.0    24.000000           1.0          1.0          1.0
# 25%         1.0   424.000000           1.0          1.0          1.0
# 50%         1.0   500.000000           1.0          1.0          1.0
# 75%         1.0   600.000000           1.0          1.0          1.0
# max         1.0  1500.000000           1.0          1.0          1.0
#
#        propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# count                      77380           77380.000000              50330
# unique                        75                    NaN               1907
# top                         0100                    NaN               LAR1
# freq                       26713                    NaN               6747
# mean                         NaN             261.826350                NaN
# std                          NaN               5.141231                NaN
# min                          NaN              31.000000                NaN
# 25%                          NaN             261.000000                NaN
# 50%                          NaN             261.000000                NaN
# 75%                          NaN             266.000000                NaN
# max                          NaN             275.000000                NaN
#
#         rawcensustractandblock   regionidcity  regionidcounty  \
# count             7.738000e+04   75909.000000    77380.000000
# unique                     NaN            NaN             NaN
# top                        NaN            NaN             NaN
# freq                       NaN            NaN             NaN
# mean              6.049130e+07   33670.128931     2534.151008
# std               2.059061e+05   47169.128504      801.595941
# min               6.037101e+07    3491.000000     1286.000000
# 25%               6.037311e+07   12447.000000     1286.000000
# 50%               6.037603e+07   25218.000000     3101.000000
# 75%               6.059042e+07   45457.000000     3101.000000
# max               6.111009e+07  396556.000000     3101.000000
#
#         regionidneighborhood    regionidzip       roomcnt  storytypeid  \
# count           30890.000000   77330.000000  77380.000000         50.0
# unique                   NaN            NaN           NaN          NaN
# top                      NaN            NaN           NaN          NaN
# freq                     NaN            NaN           NaN          NaN
# mean           187734.864066   96587.088103      1.476971          7.0
# std            165118.791740    3798.371641      2.824399          0.0
# min              6952.000000   95982.000000      0.000000          7.0
# 25%             46736.000000   96193.000000      0.000000          7.0
# 50%            118849.000000   96389.000000      0.000000          7.0
# 75%            274765.000000   96987.000000      0.000000          7.0
# max            764167.000000  399675.000000     15.000000          7.0
#
#         threequarterbathnbr  typeconstructiontypeid       unitcnt  \
# count          10096.000000              222.000000  50562.000000
# unique                  NaN                     NaN           NaN
# top                     NaN                     NaN           NaN
# freq                    NaN                     NaN           NaN
# mean               1.009608                6.040541      1.110023
# std                0.118630                0.557285      1.171166
# min                1.000000                4.000000      1.000000
# 25%                1.000000                6.000000      1.000000
# 50%                1.000000                6.000000      1.000000
# 75%                1.000000                6.000000      1.000000
# max                7.000000               13.000000    237.000000
#
#         yardbuildingsqft17  yardbuildingsqft26     yearbuilt  numberofstories  \
# count          2388.000000           70.000000  77117.000000     17560.000000
# unique                 NaN                 NaN           NaN              NaN
# top                    NaN                 NaN           NaN              NaN
# freq                   NaN                 NaN           NaN              NaN
# mean            305.411223          216.385714   1968.635943         1.434738
# std             238.392793          190.177514     23.786166         0.544569
# min              11.000000           12.000000   1824.000000         1.000000
# 25%             170.000000           61.500000   1953.000000         1.000000
# 50%             251.000000          164.500000   1970.000000         1.000000
# 75%             364.000000          310.500000   1987.000000         2.000000
# max            3191.000000          868.000000   2016.000000         6.000000
#
#         fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# count           172.0                7.726800e+04       7.737900e+04
# unique            NaN                         NaN                NaN
# top               NaN                         NaN                NaN
# freq              NaN                         NaN                NaN
# mean              1.0                1.893160e+05       4.901375e+05
# std               0.0                2.300886e+05       6.534477e+05
# min               1.0                4.400000e+01       1.000000e+03
# 25%               1.0                8.426500e+04       2.070000e+05
# 50%               1.0                1.364995e+05       3.589760e+05
# 75%               1.0                2.187875e+05       5.690030e+05
# max               1.0                1.142179e+07       4.906124e+07
#
#         assessmentyear  landtaxvaluedollarcnt      taxamount  \
# count          77380.0           7.737800e+04   77375.000000
# unique             NaN                    NaN            NaN
# top                NaN                    NaN            NaN
# freq               NaN                    NaN            NaN
# mean            2016.0           3.010969e+05    5995.566592
# std                0.0           4.925990e+05    7622.887460
# min             2016.0           1.610000e+02      19.920000
# 25%             2016.0           8.550400e+04    2715.585000
# 50%             2016.0           2.033835e+05    4450.720000
# 75%             2016.0           3.668022e+05    6927.800000
# max             2016.0           4.895220e+07  586639.300000
#
#        taxdelinquencyflag  taxdelinquencyyear  censustractandblock  \
# count                2886         2886.000000         7.713600e+04
# unique                  1                 NaN                  NaN
# top                     Y                 NaN                  NaN
# freq                 2886                 NaN                  NaN
# mean                  NaN           14.087318         6.049674e+13
# std                   NaN            2.185663         1.535252e+12
# min                   NaN            3.000000         6.037101e+13
# 25%                   NaN           14.000000         6.037311e+13
# 50%                   NaN           15.000000         6.037603e+13
# 75%                   NaN           15.000000         6.059042e+13
# max                   NaN           99.000000         4.830301e+14
#
#             logerror transactiondate airconditioningdesc  \
# count   77380.000000           77380               24953
# unique           NaN             264                   5
# top              NaN      2017-06-30             Central
# freq             NaN            1189               23133
# mean        0.016628             NaN                 NaN
# std         0.170190             NaN                 NaN
# min        -4.655420             NaN                 NaN
# 25%        -0.024377             NaN                 NaN
# 50%         0.006627             NaN                 NaN
# 75%         0.039204             NaN                 NaN
# max         5.262999             NaN                 NaN
#
#        architecturalstyledesc                               buildingclassdesc  \
# count                     206                                              15
# unique                      5                                               2
# top              Contemporary  Buildings having wood or wood and steel frames
# freq                      172                                              14
# mean                      NaN                                             NaN
# std                       NaN                                             NaN
# min                       NaN                                             NaN
# 25%                       NaN                                             NaN
# 50%                       NaN                                             NaN
# 75%                       NaN                                             NaN
# max                       NaN                                             NaN
#
#        heatingorsystemdesc        propertylandusedesc storydesc  \
# count                49439                      77380        50
# unique                  10                         13         1
# top                Central  Single Family Residential  Basement
# freq                 33550                      52319        50
# mean                   NaN                        NaN       NaN
# std                    NaN                        NaN       NaN
# min                    NaN                        NaN       NaN
# 25%                    NaN                        NaN       NaN
# 50%                    NaN                        NaN       NaN
# 75%                    NaN                        NaN       NaN
# max                    NaN                        NaN       NaN
#
#        typeconstructiondesc
# count                   222
# unique                    4
# top                   Frame
# freq                    219
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 0                    NaN                3.5         NaN
# 1                    NaN                1.0         NaN
# 2                    NaN                2.0         NaN
# 3                    8.0                3.0         NaN
# 4                    8.0                3.0         NaN
#
#    finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0                       NaN                        3100.0
# 1                    1465.0                        1465.0
# 2                       NaN                        1243.0
# 3                       NaN                        2376.0
# 4                       NaN                        1312.0
#
#    finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                3100.0                   NaN                   NaN
# 1                1465.0                   NaN                   NaN
# 2                1243.0                   NaN                   NaN
# 3                2376.0                   NaN                   NaN
# 4                1312.0                   NaN                   NaN
#
#    finishedsquarefeet50  finishedsquarefeet6    fips  fireplacecnt  \
# 0                   NaN                  NaN  6059.0           NaN
# 1                1465.0                  NaN  6111.0           1.0
# 2                   NaN                  NaN  6059.0           NaN
# 3                   NaN                  NaN  6037.0           NaN
# 4                   NaN                  NaN  6037.0           NaN
#
#    fullbathcnt  garagecarcnt  garagetotalsqft  hashottuborspa  \
# 0          3.0           2.0            633.0             NaN
# 1          1.0           1.0              0.0             NaN
# 2          2.0           2.0            440.0             NaN
# 3          3.0           NaN              NaN             NaN
# 4          3.0           NaN              NaN             NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  33634931.0 -117869207.0             4506.0      NaN
# 1                    NaN  34449266.0 -119281531.0            12647.0      NaN
# 2                    NaN  33886168.0 -117823170.0             8432.0      1.0
# 3                    2.0  34245180.0 -118240722.0            13038.0      1.0
# 4                    2.0  34185120.0 -118414640.0           278581.0      1.0
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          1.0
# 3          NaN           NaN          NaN          1.0
# 4          NaN           NaN          NaN          1.0
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                       122                  261.0                NaN
# 1                      1110                  261.0                NaN
# 2                       122                  261.0                NaN
# 3                      0101                  261.0         LCR110000*
# 4                      010C                  266.0               LAR3
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.059063e+07       53571.0          1286.0                   NaN
# 1            6.111001e+07       13091.0          2061.0                   NaN
# 2            6.059022e+07       21412.0          1286.0                   NaN
# 3            6.037300e+07      396551.0          3101.0                   NaN
# 4            6.037124e+07       12447.0          3101.0              268548.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96978.0      0.0          NaN                  1.0
# 1      97099.0      5.0          NaN                  NaN
# 2      97078.0      6.0          NaN                  NaN
# 3      96330.0      0.0          NaN                  NaN
# 4      96451.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      NaN                 NaN                 NaN
# 3                     NaN      1.0                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0     1998.0              NaN            NaN                    485713.0
# 1     1967.0              1.0            NaN                     88000.0
# 2     1962.0              1.0            NaN                     85289.0
# 3     1970.0              NaN            NaN                    108918.0
# 4     1964.0              NaN            NaN                     73681.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0          1023282.0          2016.0               537569.0   11013.72
# 1           464000.0          2016.0               376000.0    5672.48
# 2           564778.0          2016.0               479489.0    6488.30
# 3           145143.0          2016.0                36225.0    1777.51
# 4           119407.0          2016.0                45726.0    1533.89
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                NaN                 NaN         6.059063e+13  0.025595
# 1                NaN                 NaN         6.111001e+13  0.055619
# 2                NaN                 NaN         6.059022e+13  0.005383
# 3                NaN                 NaN         6.037300e+13 -0.103410
# 4                NaN                 NaN         6.037124e+13  0.006940
#
#   transactiondate airconditioningdesc architecturalstyledesc  \
# 0      2017-01-01                 NaN                    NaN
# 1      2017-01-01                 NaN                    NaN
# 2      2017-01-01                 NaN                    NaN
# 3      2017-01-01                 NaN                    NaN
# 4      2017-01-01             Central                    NaN
#
#   buildingclassdesc heatingorsystemdesc        propertylandusedesc storydesc  \
# 0               NaN                 NaN  Single Family Residential       NaN
# 1               NaN                 NaN  Single Family Residential       NaN
# 2               NaN                 NaN  Single Family Residential       NaN
# 3               NaN             Central  Single Family Residential       NaN
# 4               NaN             Central                Condominium       NaN
#
#   typeconstructiondesc
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
