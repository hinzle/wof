# %%
# current filepath system leaves plenty to be desired
import sys
local_path = '/Users/hinzlehome/codeup-data-science/natural-language-processing-exercises/'
sys.path.insert(0, local_path)

# imports.py in /utils/
from utils.imports import *

# plotting magic
# %matplotlib inline
# plotting defaults
plt.rc('figure', figsize=(16, 9))
plt.style.use('seaborn-darkgrid')
plt.rc('font', size=16)
# plt.style.available
# # ^^^ show available seaborn styles

# # !!! Warning !!! 
# # *** no more warnings ***
# import warnings
# warnings.filterwarnings("ignore")

# # custom mods
from utils.acquire import *
from utils.prepare import *
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
url = get_db_url("spam_db")
sql = "SELECT * FROM spam"

df = pd.read_sql(sql, url, index_col="id")
df.head()
# Out:
#    label                                               text
# id
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
ADDITIONAL_STOPWORDS = ['r', 'u', '2', 'ltgt']

def clean(text):
    'A simple function to cleanup text data'
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
             .encode('ascii', 'ignore')
             .decode('utf-8', 'ignore')
             .lower())
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
labels = pd.concat([df.label.value_counts(),
                    df.label.value_counts(normalize=True)], axis=1)
labels.columns = ['n', 'percent']
labels
# Out:
#          n   percent
# ham   4825  0.865937
# spam   747  0.134063

# %%
def show_counts_and_ratios(df, column):
    """
    Takes in a dataframe and a string of a single column
    Returns a dataframe with absolute value counts and percentage value counts
    """
    labels = pd.concat([df[column].value_counts(),
                    df[column].value_counts(normalize=True)], axis=1)
    labels.columns = ['n', 'percent']
    labels
    return labels

show_counts_and_ratios(df, "label")
# Out:
#          n   percent
# ham   4825  0.865937
# spam   747  0.134063

# %%
ham_words = clean(' '.join(df[df.label == 'ham'].text))
spam_words = clean(' '.join(df[df.label == 'spam'].text))
all_words = clean(' '.join(df.text))

# %%
ham_words
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'got',
#  'amore',
#  'wat',
#  'ok',
#  'lar',
#  'joking',
#  'wif',
#  'oni',
#  'dun',
#  'say',
#  'early',
#  'hor',
#  'c',
#  'already',
#  'say',
#  'nah',
#  'dont',
#  'think',
#  'go',
#  'usf',
#  'life',
#  'around',
#  'though',
#  'even',
#  'brother',
#  'like',
#  'speak',
#  'treat',
#  'like',
#  'aid',
#  'patent',
#  'per',
#  'request',
#  'melle',
#  'melle',
#  'oru',
#  'minnaminunginte',
#  'nurungu',
#  'vettam',
#  'set',
#  'callertune',
#  'caller',
#  'press',
#  '9',
#  'copy',
#  'friend',
#  'callertune',
#  'im',
#  'gonna',
#  'home',
#  'soon',
#  'dont',
#  'want',
#  'talk',
#  'stuff',
#  'anymore',
#  'tonight',
#  'k',
#  'ive',
#  'cried',
#  'enough',
#  'today',
#  'ive',
#  'searching',
#  'right',
#  'word',
#  'thank',
#  'breather',
#  'promise',
#  'wont',
#  'take',
#  'help',
#  'granted',
#  'fulfil',
#  'promise',
#  'wonderful',
#  'blessing',
#  'time',
#  'date',
#  'sunday',
#  'oh',
#  'kim',
#  'watching',
#  'eh',
#  'remember',
#  'spell',
#  'name',
#  'yes',
#  'v',
#  'naughty',
#  'make',
#  'v',
#  'wet',
#  'fine',
#  'thataos',
#  'way',
#  'feel',
#  'thataos',
#  'way',
#  'gota',
#  'b',
#  'seriously',
#  'spell',
#  'name',
#  'ium',
#  'going',
#  'try',
#  'month',
#  'ha',
#  'ha',
#  'joking',
#  'i_',
#  'pay',
#  'first',
#  'lar',
#  'da',
#  'stock',
#  'comin',
#  'aft',
#  'finish',
#  'lunch',
#  'go',
#  'str',
#  'lor',
#  'ard',
#  '3',
#  'smth',
#  'lor',
#  'finish',
#  'ur',
#  'lunch',
#  'already',
#  'ffffffffff',
#  'alright',
#  'way',
#  'meet',
#  'sooner',
#  'forced',
#  'eat',
#  'slice',
#  'im',
#  'really',
#  'hungry',
#  'tho',
#  'suck',
#  'mark',
#  'getting',
#  'worried',
#  'know',
#  'im',
#  'sick',
#  'turn',
#  'pizza',
#  'lol',
#  'lol',
#  'always',
#  'convincing',
#  'catch',
#  'bus',
#  'frying',
#  'egg',
#  'make',
#  'tea',
#  'eating',
#  'mom',
#  'left',
#  'dinner',
#  'feel',
#  'love',
#  'im',
#  'back',
#  'amp',
#  'packing',
#  'car',
#  'ill',
#  'let',
#  'know',
#  'there',
#  'room',
#  'ahhh',
#  'work',
#  'vaguely',
#  'remember',
#  'feel',
#  'like',
#  'lol',
#  'wait',
#  'thats',
#  'still',
#  'clear',
#  'sure',
#  'sarcastic',
#  'thats',
#  'x',
#  'doesnt',
#  'want',
#  'live',
#  'u',
#  'yeah',
#  'got',
#  'v',
#  'apologetic',
#  'n',
#  'fallen',
#  'actin',
#  'like',
#  'spoilt',
#  'child',
#  'got',
#  'caught',
#  'till',
#  'wont',
#  'go',
#  'badly',
#  'cheer',
#  'k',
#  'tell',
#  'anything',
#  'fear',
#  'fainting',
#  'housework',
#  'quick',
#  'cuppa',
#  'yup',
#  'ok',
#  'go',
#  'home',
#  'look',
#  'timing',
#  'msg',
#  'i_',
#  'xuhui',
#  'going',
#  'learn',
#  '2nd',
#  'may',
#  'lesson',
#  '8am',
#  'oops',
#  'ill',
#  'let',
#  'know',
#  'roommate',
#  'done',
#  'see',
#  'letter',
#  'b',
#  'car',
#  'anything',
#  'lor',
#  'decide',
#  'hello',
#  'hows',
#  'saturday',
#  'go',
#  'texting',
#  'see',
#  'youd',
#  'decided',
#  'anything',
#  'tomo',
#  'im',
#  'trying',
#  'invite',
#  'anything',
#  'pls',
#  'go',
#  'ahead',
#  'watt',
#  'wanted',
#  'sure',
#  'great',
#  'weekend',
#  'abiola',
#  'forget',
#  'tell',
#  'want',
#  'need',
#  'crave',
#  'love',
#  'sweet',
#  'arabian',
#  'steed',
#  'mmmmmm',
#  'yummy',
#  'seeing',
#  'great',
#  'hope',
#  'like',
#  'man',
#  'well',
#  'endowed',
#  'inch',
#  'callsmessagesmissed',
#  'call',
#  'didnt',
#  'get',
#  'hep',
#  'b',
#  'immunisation',
#  'nigeria',
#  'fair',
#  'enough',
#  'anything',
#  'going',
#  'yeah',
#  'hopefully',
#  'tyler',
#  'cant',
#  'could',
#  'maybe',
#  'ask',
#  'around',
#  'bit',
#  'dont',
#  'know',
#  'stubborn',
#  'didnt',
#  'even',
#  'want',
#  'go',
#  'hospital',
#  'kept',
#  'telling',
#  'mark',
#  'im',
#  'weak',
#  'sucker',
#  'hospital',
#  'weak',
#  'sucker',
#  'thinked',
#  'first',
#  'time',
#  'saw',
#  'class',
#  'gram',
#  'usually',
#  'run',
#  'like',
#  'half',
#  'eighth',
#  'smarter',
#  'though',
#  'get',
#  'almost',
#  'whole',
#  'second',
#  'gram',
#  'k',
#  'fyi',
#  'x',
#  'ride',
#  'early',
#  'tomorrow',
#  'morning',
#  'he',
#  'crashing',
#  'place',
#  'tonight',
#  'wow',
#  'never',
#  'realized',
#  'embarassed',
#  'accomodations',
#  'thought',
#  'liked',
#  'since',
#  'best',
#  'could',
#  'always',
#  'seemed',
#  'happy',
#  'cave',
#  'im',
#  'sorry',
#  'didnt',
#  'dont',
#  'give',
#  'im',
#  'sorry',
#  'offered',
#  'im',
#  'sorry',
#  'room',
#  'embarassing',
#  'know',
#  'mallika',
#  'sherawat',
#  'yesterday',
#  'find',
#  'lturlgt',
#  'sorry',
#  'ill',
#  'call',
#  'later',
#  'meeting',
#  'tell',
#  'reached',
#  'yesgauti',
#  'sehwag',
#  'odi',
#  'series',
#  'gonna',
#  'pick',
#  '1',
#  'burger',
#  'way',
#  'home',
#  'cant',
#  'even',
#  'move',
#  'pain',
#  'killing',
#  'ha',
#  'ha',
#  'ha',
#  'good',
#  'joke',
#  'girl',
#  'situation',
#  'seeker',
#  'part',
#  'checking',
#  'iq',
#  'sorry',
#  'roommate',
#  'took',
#  'forever',
#  'ok',
#  'come',
#  'ok',
#  'lar',
#  'double',
#  'check',
#  'wif',
#  'da',
#  'hair',
#  'dresser',
#  'already',
#  'said',
#  'wun',
#  'cut',
#  'v',
#  'short',
#  'said',
#  'cut',
#  'look',
#  'nice',
#  'today',
#  'song',
#  'dedicated',
#  'day',
#  'song',
#  'dedicate',
#  'send',
#  'ur',
#  'valuable',
#  'frnds',
#  'first',
#  'rply',
#  'plane',
#  'give',
#  'month',
#  'end',
#  'wah',
#  'lucky',
#  'man',
#  'save',
#  'money',
#  'hee',
#  'finished',
#  'class',
#  'hi',
#  'babe',
#  'im',
#  'home',
#  'wanna',
#  'something',
#  'xx',
#  'kkwhere',
#  'youhow',
#  'performed',
#  'call',
#  'waiting',
#  'machan',
#  'call',
#  'free',
#  'thats',
#  'cool',
#  'gentleman',
#  'treat',
#  'dignity',
#  'respect',
#  'like',
#  'people',
#  'much',
#  'shy',
#  'pa',
#  'operate',
#  'still',
#  'looking',
#  'job',
#  'much',
#  'ta',
#  'earn',
#  'sorry',
#  'ill',
#  'call',
#  'later',
#  'k',
#  'call',
#  'ah',
#  'ok',
#  'way',
#  'home',
#  'hi',
#  'hi',
#  'place',
#  'man',
#  'yup',
#  'next',
#  'stop',
#  'call',
#  'later',
#  'dont',
#  'network',
#  'urgnt',
#  'sm',
#  'real',
#  'getting',
#  'yo',
#  'need',
#  'ticket',
#  'one',
#  'jacket',
#  'im',
#  'done',
#  'already',
#  'used',
#  'multis',
#  'yes',
#  'started',
#  'send',
#  'request',
#  'make',
#  'pain',
#  'came',
#  'back',
#  'im',
#  'back',
#  'bed',
#  'double',
#  'coin',
#  'factory',
#  'gotta',
#  'cash',
#  'nitros',
#  'im',
#  'really',
#  'still',
#  'tonight',
#  'babe',
#  'ela',
#  'kanoil',
#  'download',
#  'come',
#  'wen',
#  'ur',
#  'free',
#  'yeah',
#  'donut',
#  'stand',
#  'close',
#  'tho',
#  'youull',
#  'catch',
#  'something',
#  'sorry',
#  'pain',
#  'ok',
#  'meet',
#  'another',
#  'night',
#  'spent',
#  'late',
#  'afternoon',
#  'casualty',
#  'mean',
#  'havent',
#  'done',
#  'stuff42moro',
#  'includes',
#  'time',
#  'sheet',
#  'sorry',
#  'smile',
#  'pleasure',
#  'smile',
#  'pain',
#  'smile',
#  'trouble',
#  'pours',
#  'like',
#  'rain',
#  'smile',
#  'sum1',
#  'hurt',
#  'smile',
#  'becoz',
#  'someone',
#  'still',
#  'love',
#  'see',
#  'smiling',
#  'havent',
#  'planning',
#  'buy',
#  'later',
#  'check',
#  'already',
#  'lido',
#  'got',
#  '530',
#  'show',
#  'e',
#  'afternoon',
#  'finish',
#  'work',
#  'already',
#  'watching',
#  'telugu',
#  'moviewat',
#  'abt',
#  'see',
#  'finish',
#  'load',
#  'loan',
#  'pay',
#  'hi',
#  'wk',
#  'ok',
#  'hols',
#  'yes',
#  'bit',
#  'run',
#  'forgot',
#  'hairdresser',
#  'appointment',
#  'four',
#  'need',
#  'get',
#  'home',
#  'n',
#  'shower',
#  'beforehand',
#  'cause',
#  'prob',
#  'ham',
#  'please',
#  'dont',
#  'text',
#  'anymore',
#  'nothing',
#  'else',
#  'say',
#  'okay',
#  'name',
#  'ur',
#  'price',
#  'long',
#  'legal',
#  'wen',
#  'pick',
#  'ave',
#  'x',
#  'am',
#  'xx',
#  'im',
#  'still',
#  'looking',
#  'car',
#  'buy',
#  'gone',
#  '4the',
#  'driving',
#  'test',
#  'yet',
#  'per',
#  'request',
#  'melle',
#  'melle',
#  'oru',
#  'minnaminunginte',
#  'nurungu',
#  'vettam',
#  'set',
#  'callertune',
#  'caller',
#  'press',
#  '9',
#  'copy',
#  'friend',
#  'callertune',
#  'wow',
#  'youre',
#  'right',
#  'didnt',
#  'mean',
#  'guess',
#  'gave',
#  'boston',
#  'men',
#  'changed',
#  'search',
#  'location',
#  'nyc',
#  'something',
#  'changed',
#  'cuz',
#  'signin',
#  'page',
#  'still',
#  'say',
#  'boston',
#  'umma',
#  'life',
#  'vava',
#  'umma',
#  'love',
#  'lot',
#  'dear',
#  'thanks',
#  'lot',
#  'wish',
#  'birthday',
#  'thanks',
#  'making',
#  'birthday',
#  'truly',
#  'memorable',
#  'aight',
#  'ill',
#  'hit',
#  'get',
#  'cash',
#  'would',
#  'ip',
#  'address',
#  'test',
#  'considering',
#  'computer',
#  'isnt',
#  'minecraft',
#  'server',
#  'know',
#  'grumpy',
#  'old',
#  'people',
#  'mom',
#  'like',
#  'better',
#  'lying',
#  'always',
#  'one',
#  'play',
#  'joke',
#  'dont',
#  'worry',
#  'guess',
#  'he',
#  'busy',
#  'plural',
#  'noun',
#  'research',
#  'going',
#  'dinnermsg',
#  'im',
#  'ok',
#  'wif',
#  'co',
#  'like',
#  'try',
#  'new',
#  'thing',
#  'scared',
#  'dun',
#  'like',
#  'mah',
#  'co',
#  'said',
#  'loud',
#  'wa',
#  'ur',
#  'openin',
#  'sentence',
#  'formal',
#  'anyway',
#  'im',
#  'fine',
#  'juz',
#  'tt',
#  'im',
#  'eatin',
#  'much',
#  'n',
#  'puttin',
#  'weighthaha',
#  'anythin',
#  'special',
#  'happened',
#  'entered',
#  'cabin',
#  'pa',
#  'said',
#  'happy',
#  'bday',
#  'bos',
#  'felt',
#  'special',
#  'askd',
#  '4',
#  'lunch',
#  'lunch',
#  'invited',
#  'apartment',
#  'went',
#  'goodo',
#  'yes',
#  'must',
#  'speak',
#  'friday',
#  'eggpotato',
#  'ratio',
#  'tortilla',
#  'needed',
#  'hmmmy',
#  'uncle',
#  'informed',
#  'he',
#  'paying',
#  'school',
#  'directly',
#  'pls',
#  'buy',
#  'food',
#  'new',
#  'address',
#  'applespairsall',
#  'malarky',
#  'going',
#  'sao',
#  'mu',
#  'today',
#  'done',
#  '12',
#  'ii',
#  'predict',
#  'wat',
#  'time',
#  'i_ll',
#  'finish',
#  'buying',
#  'good',
#  'stuff',
#  'knowyetunde',
#  'hasnt',
#  'sent',
#  'money',
#  'yet',
#  'sent',
#  'text',
#  'bother',
#  'sending',
#  'dont',
#  'involve',
#  'anything',
#  'shouldnt',
#  'imposed',
#  'anything',
#  'first',
#  'place',
#  'apologise',
#  'room',
#  'hey',
#  'girl',
#  'hope',
#  'well',
#  'del',
#  'bak',
#  'long',
#  'time',
#  'c',
#  'give',
#  'call',
#  'sum',
#  'time',
#  'lucyxx',
#  'kkhow',
#  'much',
#  'cost',
#  'im',
#  'home',
#  'dear',
#  'call',
#  'tmorrowpls',
#  'accomodate',
#  'first',
#  'answer',
#  'question',
#  'haf',
#  'msn',
#  'yijuehotmailcom',
#  'call',
#  'meet',
#  'check',
#  'room',
#  'befor',
#  'activity',
#  'got',
#  'c',
#  'lazy',
#  'type',
#  'forgot',
#  'i_',
#  'lect',
#  'saw',
#  'pouch',
#  'like',
#  'v',
#  'nice',
#  'k',
#  'text',
#  'youre',
#  'way',
#  'sir',
#  'waiting',
#  'mail',
#  'swt',
#  'thought',
#  'nver',
#  'get',
#  'tired',
#  'little',
#  'thing',
#  '4',
#  'lovable',
#  'person',
#  'cozsomtimes',
#  'little',
#  'thing',
#  'occupy',
#  'biggest',
#  'part',
#  'heart',
#  'gud',
#  'ni8',
#  'know',
#  'pls',
#  'open',
#  'back',
#  'yes',
#  'see',
#  'ya',
#  'dot',
#  'whats',
#  'staff',
#  'name',
#  'taking',
#  'class',
#  'u',
#  'ummmawill',
#  'call',
#  'check',
#  'inour',
#  'life',
#  'begin',
#  'qatar',
#  'pls',
#  'pray',
#  'hard',
#  'ki',
#  'deleted',
#  'contact',
#  'sindu',
#  'got',
#  'job',
#  ...]

# %%
ham_freq = pd.Series(ham_words).value_counts()
spam_freq = pd.Series(spam_words).value_counts()
all_freq = pd.Series(all_words).value_counts()

spam_freq.head()
# Out:
# call    359
# free    216
# txt     150
# ur      144
# text    137
# dtype: int64

# %%
word_counts = (pd.concat([all_freq, ham_freq, spam_freq], axis=1, sort=True)
                .set_axis(['all', 'ham', 'spam'], axis=1, inplace=False)
                .fillna(0)
                .apply(lambda s: s.astype(int)))

word_counts.head()
# Out:
#               all  ham  spam
# 0               3    0     3
# 008704050406    2    0     2
# 0089my          1    0     1
# 0121            1    0     1
# 01223585236     1    0     1

# %%
word_counts.sort_values(by='all', ascending=False).head(10)
# Out:
#       all  ham  spam
# call  600  241   359
# im    462  449    13
# get   397  314    83
# ur    384  240   144
# go    304  273    31
# 4     287  168   119
# dont  279  257    22
# ok    277  272     5
# free  275   59   216
# know  267  241    26

# %%
pd.concat([word_counts[word_counts.spam == 0].sort_values(by='ham').tail(6),
           word_counts[word_counts.ham == 0].sort_values(by='spam').tail(6)])
# Out:
#             all  ham  spam
# thats        94   94     0
# i_          117  117     0
# say         118  118     0
# da          132  132     0
# later       134  134     0
# lor         160  160     0
# awarded      38    0    38
# 18           43    0    43
# guaranteed   50    0    50
# tone         73    0    73
# prize        94    0    94
# claim       115    0   115

# %%
# figure out the percentage of spam vs ham
(word_counts
 .assign(p_spam=word_counts.spam / word_counts['all'],
         p_ham=word_counts.ham / word_counts['all'])
 .sort_values(by='all')
 [['p_spam', 'p_ham']]
 .tail(20)
 .sort_values('p_ham')
 .plot.barh(stacked=True))

plt.title('Proportion of Spam vs Ham for the 20 most common words')
# Out:
# Text(0.5, 1.0, 'Proportion of Spam vs Ham for the 20 most common words')

# %%
(word_counts
 [(word_counts.spam > 10) & (word_counts.ham > 10)]
 .assign(ratio=lambda df: df.spam / (df.ham + .01))
 .sort_values(by='ratio')
 .pipe(lambda df: pd.concat([df.head(), df.tail()])))
# Out:
#          all  ham  spam      ratio
# im       462  449    13   0.028953
# good     235  223    12   0.053809
# like     245  232    13   0.056032
# need     182  171    11   0.064324
# dont     279  257    22   0.085600
# contact   70   14    56   3.997145
# win       76   15    61   4.063957
# cash      74   12    62   5.162365
# mobile   150   15   135   8.994004
# txt      163   13   150  11.529593

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   5572 non-null   object
#  1   text    5572 non-null   object
# dtypes: object(2)
# memory usage: 130.6+ KB

# %%
df[df.label=='ham'].text
# Out:
# id
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
# 6       Even my brother is not like to speak with me. ...
# 7       As per your request 'Melle Melle (Oru Minnamin...
# 10      I'm gonna be home soon and i don't want to tal...
# 13      I've been searching for the right words to tha...
# 14                    I HAVE A DATE ON SUNDAY WITH WILL!!
# 16                             Oh k...i'm watching here:)
# 17      Eh u remember how 2 spell his name... Yes i di...
# 18      Fine if thatåÕs the way u feel. ThatåÕs the wa...
# 20              Is that seriously how you spell his name?
# 21      IÛ÷m going to try for 2 months ha ha only joking
# 22      So Ì_ pay first lar... Then when is da stock c...
# 23      Aft i finish my lunch then i go str down lor. ...
# 24      Ffffffffff. Alright no way I can meet up with ...
# 25      Just forced myself to eat a slice. I'm really ...
# 26                         Lol your always so convincing.
# 27      Did you catch the bus ? Are you frying an egg ...
# 28      I'm back &amp; we're packing the car now, I'll...
# 29      Ahhh. Work. I vaguely remember that! What does...
# 30      Wait that's still not all that clear, were you...
# 31      Yeah he got in at 2 and was v apologetic. n ha...
# 32                          K tell me anything about you.
# 33      For fear of fainting with the of all that hous...
# 35      Yup... Ok i go home look at the timings then i...
# 36        Oops, I'll let you know when my roommate's done
# 37                           I see the letter B on my car
# 38                            Anything lor... U decide...
# 39      Hello! How's you and how did saturday go? I wa...
# 40      Pls go ahead with watts. I just wanted to be s...
# 41      Did I forget to tell you ? I want you , I need...
# 43                                    WHO ARE YOU SEEING?
# 44      Great! I hope you like your man well endowed. ...
# 45                       No calls..messages..missed calls
# 46          Didn't you get hep b immunisation in nigeria.
# 47                        Fair enough, anything going on?
# 48      Yeah hopefully, if tyler can't do it I could m...
# 49      U don't know how stubborn I am. I didn't even ...
# 50      What you thinked about me. First time you saw ...
# 51      A gram usually runs like  &lt;#&gt; , a half e...
# 52      K fyi x has a ride early tomorrow morning but ...
# 53      Wow. I never realized that you were so embaras...
# 55      Do you know what Mallika Sherawat did yesterda...
# 57                     Sorry, I'll call later in meeting.
# 58                                 Tell where you reached
# 59               Yes..gauti and sehwag out of odi series.
# 60      Your gonna have to pick up a $1 burger for you...
# 61       Ha ha ha good joke. Girls are situation seekers.
# 62                              Its a part of checking IQ
# 63      Sorry my roommates took forever, it ok if I co...
# 64      Ok lar i double check wif da hair dresser alre...
# 66      Today is \song dedicated day..\" Which song wi...
# 69                     I plane to give on this month end.
# 70         Wah lucky man... Then can save money... Hee...
# 71                          Finished class where are you.
# 72          HI BABE IM AT HOME NOW WANNA DO SOMETHING? XX
# 73             K..k:)where are you?how did you performed?
# 74                                   U can call me now...
# 75            I am waiting machan. Call me once you free.
# 76      Thats cool. i am a gentleman and will treat yo...
# 77      I like you peoples very much:) but am very shy...
# 78             Does not operate after  &lt;#&gt;  or what
# 79      Its not the same here. Still looking for a job...
# 80                                 Sorry, I'll call later
# 81                       K. Did you call me just now ah?
# 82                       Ok i am on the way to home hi hi
# 83                   You will be in the place of that man
# 84                                         Yup next stop.
# 85      I call you later, don't have network. If urgnt...
# 86      For real when u getting on yo? I only need 2 m...
# 87      Yes I started to send requests to make it but ...
# 88             I'm really not up to it still tonight babe
# 89              Ela kano.,il download, come wen ur free..
# 90      Yeah do! DonÛ÷t stand to close tho- youÛ÷ll ...
# 91      Sorry to be a pain. Is it ok if we meet anothe...
# 92      Smile in Pleasure Smile in Pain Smile when tro...
# 94      Havent planning to buy later. I check already ...
# 96                      Watching telugu movie..wat abt u?
# 97      i see. When we finish we have loads of loans t...
# 98      Hi. Wk been ok - on hols now! Yes on for a bit...
# 99      Please don't text me anymore. I have nothing e...
# 100     Okay name ur price as long as its legal! Wen c...
# 101     I'm still looking for a car to buy. And have n...
# 102     As per your request 'Melle Melle (Oru Minnamin...
# 103     wow. You're right! I didn't mean to do that. I...
# 104          Umma my life and vava umma love you lot dear
# 105     Thanks a lot for your wishes on my birthday. T...
# 106           Aight, I'll hit you up when I get some cash
# 107     How would my ip address test that considering ...
# 108     I know! Grumpy old people. My mom was like you...
# 109                        Dont worry. I guess he's busy.
# 110              What is the plural of the noun research?
# 111                       Going for dinner.msg you after.
# 112     I'm ok wif it cos i like 2 try new things. But...
# 114     Wa, ur openin sentence very formal... Anyway, ...
# 115     As I entered my cabin my PA said, '' Happy B'd...
# 117     Goodo! Yes we must speak friday - egg-potato r...
# 118     Hmm...my uncle just informed me that he's payi...
# 121     here is my new address -apples&pairs&all that ...
# 123     I am going to sao mu today. Will be done only ...
# 124              ÌÏ predict wat time Ì_'ll finish buying?
# 125                                  Good stuff, will do.
# 126     Just so that you know,yetunde hasn't sent mone...
# 127                                Are you there in room.
# 128     HEY GIRL. HOW R U? HOPE U R WELL ME AN DEL R B...
# 129                          K..k:)how much does it cost?
# 130                                             I'm home.
# 131               Dear, will call Tmorrow.pls accomodate.
# 132                             First answer my question.
# 135                I only haf msn. It's yijue@hotmail.com
# 136                    He is there. You call and meet him
# 137        No no. I will check all rooms befor activities
# 139     Got c... I lazy to type... I forgot Ì_ in lect...
# 140                     K, text me when you're on the way
# 141                           Sir, Waiting for your mail.
# 142     A swt thought: \Nver get tired of doing little...
# 143            I know you are. Can you pls open the back?
# 144                             Yes see ya not on the dot
# 145      Whats the staff name who is taking class for us?
# 147     Ummma.will call after check in.our life will b...
# 148                     K..i deleted my contact that why?
# 149                        Sindu got job in birla soft ..
# 150         The wine is flowing and i'm i have nevering..
# 151     Yup i thk cine is better cos no need 2 go down...
# 152                             Ok... Ur typical reply...
# 153     As per your request 'Melle Melle (Oru Minnamin...
# 154     You are everywhere dirt, on the floor, the win...
# 155                          Aaooooright are you at work?
# 156                           I'm leaving my house now...
# 157     Hello, my love. What are you doing? Did you ge...
# 160     Keep yourself safe for me because I need you a...
# 161     New car and house for my parents.:)i have only...
# 162     I'm so in love with you. I'm excited each day ...
# 165     I place all ur points on e cultures module alr...
# 167     Hi frnd, which is best way to avoid missunders...
# 168     Great escape. I fancy the bridge but needs her...
# 169     Yes :)it completely in out of form:)clark also...
# 170     Sir, I need AXIS BANK account no and bank addr...
# 171     Hmmm.. Thk sure got time to hop ard... Ya, can...
# 172                     What time you coming down later?
# 173     Bloody hell, cant believe you forgot my surnam...
# 174     Well, i'm gonna finish my bath now. Have a goo...
# 175     Let me know when you've got the money so carlo...
# 176                            U still going to the mall?
# 177     Turns out my friends are staying for the whole...
# 178     Text her. If she doesnt reply let me know so i...
# 179     Hi! You just spoke to MANEESHA V. We'd like to...
# 180     You lifted my hopes with the offer of money. I...
# 181                               Lol no. U can trust me.
# 182     ok. I am a gentleman and will treat you with d...
# 183                              He will, you guys close?
# 184                            Going on nothing great.bye
# 185     Hello handsome ! Are you finding that job ? No...
# 186                    Haha awesome, be there in a minute
# 188     Have you got Xmas radio times. If not i will g...
# 189     I jus reached home. I go bathe first. But my s...
# 191     I'm sorry. I've joined the league of people th...
# 192                 Hi :)finally i completed the course:)
# 193     It will stop on itself. I however suggest she ...
# 194     How are you doing? Hope you've settled in for ...
# 195                          Gud mrng dear hav a nice day
# 196                          Did u got that persons story
# 197     is your hamster dead? Hey so tmr i meet you at...
# 198     Hi its Kate how is your evening? I hope i can ...
# 199              Found it, ENC  &lt;#&gt; , where you at?
# 200                          I sent you  &lt;#&gt;  bucks
# 201     Hello darlin ive finished college now so txt m...
# 202     Your account has been refilled successfully by...
# 203                              Goodmorning sleeping ga.
# 204                             U call me alter at 11 ok.
# 205     ÌÏ say until like dat i dun buy ericsson oso c...
# 206     As I entered my cabin my PA said, '' Happy B'd...
# 207                          Aight yo, dats straight dogg
# 208     You please give us connection today itself bef...
# 209               Both :) i shoot big loads so get ready!
# 210     What's up bruv, hope you had a great break. Do...
# 211                            Home so we can always chat
# 212                               K:)k:)good:)study well.
# 213                              Yup... How Ì_ noe leh...
# 214                       Sounds great! Are you home now?
# 215     Finally the match heading towards draw as your...
# 216      Tired. I haven't slept well the past few nights.
# 217             Easy ah?sen got selected means its good..
# 218                      I have to take exam with march 3
# 219     Yeah you should. I think you can use your gt a...
# 220                             Ok no prob. Take ur time.
# 221     There is os called ubandu which will run witho...
# 222                                Sorry, I'll call later
# 223     U say leh... Of course nothing happen lar. Not...
# 225     Would really appreciate if you call me. Just n...
# 227                        Hey company elama po mudyadhu.
# 228     Life is more strict than teacher... Bcoz Teach...
# 229                    Dear good morning now only i am up
# 230     Get down in gandhipuram and walk to cross cut ...
# 231                 Dear we are going to our rubber place
# 232                     Sorry battery died, yeah I'm here
# 233      Yes:)here tv is always available in work place..
# 235     I have printed it oh. So  &lt;#&gt;  come upst...
# 236     Or ill be a little closer like at the bus stop...
# 237                Where are you?when wil you reach here?
# 238     New Theory: Argument wins d SITUATION, but los...
# 240     Tomarrow final hearing on my laptop case so i ...
# 241         PLEASSSSSSSEEEEEE TEL ME V AVENT DONE SPORTSx
# 242     Okay. No no, just shining on. That was meant t...
# 243     Although i told u dat i'm into baig face watch...
# 244                 U don't remember that old commercial?
# 245     Too late. I said i have the website. I didn't ...
# 246                        I asked you to call him now ok
# 247                       Kallis wont bat in 2nd innings.
# 248     It didnt work again oh. Ok goodnight then. I.l...
# 250          Ranjith cal drpd Deeraj and deepak 5min hold
# 251     Wen ur lovable bcums angry wid u, dnt take it ...
# 252                           What you doing?how are you?
# 253     Ups which is 3days also, and the shipping comp...
# 254                I'm back, lemme know when you're ready
# 255     Don't necessarily expect it to be done before ...
# 256           Mmm so yummy babe ... Nice jolt to the suzy
# 257                  Where are you lover ? I need you ...
# 259     IÛ÷m parked next to a MINI!!!! When are you c...
# 260                                                   Yup
# 261     Anyway i'm going shopping on my own now. Cos m...
# 262     MY NO. IN LUTON 0125698789 RING ME IF UR AROUN...
# 264                            Why you Dint come with us.
# 265                   Same. Wana plan a trip sometme then
# 266       Not sure yet, still trying to get a hold of him
# 268       The evo. I just had to download flash. Jealous?
# 270     Come to mu, we're sorting out our narcotics si...
# 271     Night has ended for another day, morning has c...
# 273                 Usf I guess, might as well take 1 car
# 274                       No objection. My bf not coming.
# 275                                              Thanx...
# 276                Tell rob to mack his gf in the theater
# 277                        Awesome, I'll see you in a bit
# 278       Just sent it. So what type of food do you like?
# 279     All done? All handed in? Celebrations in full ...
# 280                                You got called a tool?
# 281                                   \Wen u miss someone
# 282                         Ok. I asked for money how far
# 283                                               Okie...
# 284     Yeah I think my usual guy's still passed out f...
# 285     K, I might come by tonight then if my class le...
# 286                                                  Ok..
# 287     hi baby im cruisin with my girl friend what r ...
# 288     My life Means a lot to me, Not because I love ...
# 289     Dear,shall mail tonite.busy in the street,shal...
# 290                 Hey you told your name to gautham ah?
# 291     Haf u found him? I feel so stupid da v cam was...
# 292                                 Oops. 4 got that bit.
# 293                                Are you this much buzy
# 294     I accidentally deleted the message. Resend ple...
# 296     Unless it's a situation where YOU GO GURL woul...
# 297     Hurt me... Tease me... Make me cry... But in t...
# 298     I cant pick the phone right now. Pls send a me...
# 299     Need a coffee run tomo?Can't believe it's that...
# 300     Awesome, I remember the last time we got someb...
# 301     Shit that is really shocking and scary, cant i...
# 302     Oh and by the way you do have more food in you...
# 303                              He is a womdarfull actor
# 305     Yup... From what i remb... I think should be c...
# 306                            Jos ask if u wana meet up?
# 307     Lol yes. Our friendship is hanging on a thread...
# 309     Where are the garage keys? They aren't on the ...
# 310     Today is ACCEPT DAY..U Accept me as? Brother S...
# 312     He says he'll give me a call when his friend's...
# 313     Hi the way I was with u 2day, is the normal wa...
# 314             You made my day. Do have a great day too.
# 315                            K.k:)advance happy pongal.
# 316     Hmmm... Guess we can go 4 kb n power yoga... H...
# 317        Not really dude, have no friends i'm afraid :(
# 319                               Coffee cake, i guess...
# 320     Merry Christmas to you too babe, i love ya *ki...
# 321     Hey... Why dont we just go watch x men and hav...
# 322     cud u tell ppl im gona b a bit l8 cos 2 buses ...
# 323     That would be great. We'll be at the Guild. Co...
# 324                        No problem. How are you doing?
# 325                      No calls..messages..missed calls
# 326                       Hi da:)how is the todays class?
# 327     I'd say that's a good sign but, well, you know...
# 328                      Cool, text me when you're parked
# 329     I'm reading the text i just sent you. Its mean...
# 330                                K.k:)apo k.good movie.
# 331     Maybe i could get book out tomo then return it...
# 333     Any chance you might have had with me evaporat...
# 335         Ta-Daaaaa! I am home babe, are you still up ?
# 336     Cool. So how come you havent been wined and di...
# 337                            Just sleeping..and surfing
# 338                                Sorry, I'll call later
# 339             U calling me right? Call my hand phone...
# 340                          Ok that's great thanx a lot.
# 341     I take it the post has come then! You must hav...
# 342                         Where u been hiding stranger?
# 343                    Am not interested to do like that.
# 344     My sister cleared two round in birla soft yest...
# 345                     Gudnite....tc...practice going on
# 346     Dis is yijue. I jus saw ur mail. In case huimi...
# 347                       One small prestige problem now.
# 349     Just checking in on you. Really do miss seeing...
# 350     Nah can't help you there, I've never had an ip...
# 351     If you're not in my car in an hour and a half ...
# 352     TODAY is Sorry day.! If ever i was angry with ...
# 353     Yo you guys ever figure out how much we need f...
# 354         &lt;#&gt; ISH MINUTES WAS 5 MINUTES AGO. WTF
EY HEY WERETHE MONKEESPEOPLE SAY WE MONKEYAR...
# 445     Sorry, my battery died, I can come by but I'm ...
# 446     Well done, blimey, exercise, yeah, i kinda rem...
# 447     I wont get concentration dear you know you are...
# 448            LOL ... Have you made plans for new years?
# 449                                     10 min later k...
# 450                                         hanks lotsly!
# 451         Thanks for this hope you had a good day today
# 452     K:)k:)what are detail you want to transfer?acc...
# 453     Ok i will tell her to stay out. Yeah its been ...
# 455       Si si. I think ill go make those oreo truffles.
# 456     LOOK AT AMY URE A BEAUTIFUL, INTELLIGENT WOMAN...
# 457     I hope you that's the result of being consiste...
# 458     1.20 that call cost. Which i guess isnt bad. M...
# 459     Going thru a very different feeling.wavering d...
# 460     Where did u go? My phone is gonna die you have...
# 461     Great. Never been better. Each day gives even ...
# 463                         Sorry, I'll call later ok bye
# 464                         Ok i am on the way to railway
# 465     great princess! I love giving and receiving or...
# 466     They don't put that stuff on the roads to keep...
# 467                 When are you going to ride your bike?
# 468          Yup, no need. I'll jus wait 4 e rain 2 stop.
# 469         There are many company. Tell me the language.
# 471     How long has it been since you screamed, princ...
# 472     Nothing. I meant that once the money enters yo...
# 474     Nice line said by a broken heart- Plz don't cu...
# 475     Ok I'm gonna head up to usf in like fifteen mi...
# 476                          Love you aathi..love u lot..
# 477                    Tension ah?what machi?any problem?
# 478        K, can I pick up another 8th when you're done?
# 479     When're you guys getting back? G said you were...
# 480                          Almost there, see u in a sec
# 481     Yo carlos, a few friends are already asking me...
# 482                                    Watching tv lor...
# 483     Thank you baby! I cant wait to taste the real ...
# 484     You should change your fb to jaykwon thuglyfe ...
# 485         If we win its really no 1 side for long time.
# 487              Dear reached railway. What happen to you
# 488     Depends on quality. If you want the type i sen...
# 489     I think i've fixed it can you send a test mess...
# 490     Sorry man my account's dry or I would, if you ...
# 492                      Sorry,in meeting I'll call later
# 493                    What class of  &lt;#&gt;  reunion?
# 494                      Are you free now?can i call now?
# 495                                      Got meh... When?
# 496     Nope... Think i will go for it on monday... So...
# 497     Some of them told accenture is not confirm. Is...
# 498           Kate jackson rec center before 7ish, right?
# 499                               Dear i have reache room
# 500     Fighting with the world is easy, u either win ...
# 501                                 When can Ì_ come out?
# 502                               Check with nuerologist.
# 503              Lolnice. I went from a fish to ..water.?
# 505     No it's waiting in e car dat's bored wat. Cos ...
# 506     Maybe westshore or hyde park village, the plac...
# 507     You should know now. So how's anthony. Are you...
# 508                              What's the significance?
# 509     Your opinion about me? 1. Over 2. Jada 3. Kusr...
# 510     8 at the latest, g's still there if you can sc...
# 511         Prabha..i'm soryda..realy..frm heart i'm sory
# 512                               Lol ok your forgiven :)
# 513                             No..jst change tat only..
# 515                            S:)no competition for him.
# 518     That way transport is less problematic than on...
# 519     Usually the person is unconscious that's in ch...
# 520        But that's on ebay it might be less elsewhere.
# 521                            Shall i come to get pickle
# 522                          Were gonna go get some tacos
# 523                      That's very rude, you on campus?
# 525     Hi i won't b ard 4 christmas. But do enjoy n m...
# 527            Yes! How is a pretty lady like you single?
# 529                  Jay says that you're a double-faggot
# 531     What Today-sunday..sunday is holiday..so no wo...
# 532                     Gudnite....tc...practice going on
# 533                                       I'll be late...
# 534     I've not called you in a while. This is hoping...
# 535     Good afternoon, my love! How goes that day ? I...
# 536     Probably gonna be here for a while, see you la...
# 537     Or maybe my fat fingers just press all these b...
# 538     Ummmmmaah Many many happy returns of d day my ...
# 539     I am in tirupur da, once you started from offi...
# 541     A famous quote : when you develop the ability ...
# 542     But am going to college pa. What to do. are el...
# 543       4 oclock at mine. Just to bash out a flat plan.
# 544     This girl does not stay in bed. This girl does...
# 545                               Then any special there?
# 546     I know but you need to get hotel now. I just g...
# 547                      Sorry that took so long, omw now
# 548                                Wait  &lt;#&gt;  min..
# 549     Ok give me 5 minutes I think I see her. BTW yo...
# 550     Imagine you finally get to sink into that bath...
# 551     Hurry up, I've been weed-deficient for like th...
# 552     Sure, if I get an acknowledgement from you tha...
# 553     Ok. Every night take a warm bath drink a cup o...
# 554     IÛ÷ll have a look at the frying pan in case i...
# 555     O. Well uv causes mutations. Sunscreen is like...
# 556              Having lunch:)you are not in online?why?
# 557              I know that my friend already told that.
# 558     Hi Princess! Thank you for the pics. You are v...
# 559     Aiyo... U always c our ex one... I dunno abt m...
# 560                            Hi msg me:)i'm in office..
# 561                      Thanx 4 e brownie it's v nice...
# 562     Geeeee ... I love you so much I can barely sta...
# 564     Fuck babe ... I miss you already, you know ? C...
# 565     Ill call u 2mrw at ninish, with my address tha...
# 566         Oooh bed ridden ey? What are YOU thinking of?
# 567     So anyways, you can just go to your gym or wha...
# 568     Love it! Daddy will make you scream with pleas...
# 569                            WOT U WANNA DO THEN MISSY?
# 570     Yar lor wait 4 my mum 2 finish sch then have l...
# 571                 Do you know where my lab goggles went
# 572                                Can you open the door?
# 573                                Waiting for your call.
# 574                     Nope i waiting in sch 4 daddy...
# 576     I'm tired of arguing with you about this week ...
# 577                  ÌÏ wait 4 me in sch i finish ard 5..
# 579     Arngd marriage is while u r walkin unfortuntly...
# 580     Huh so early.. Then Ì_ having dinner outside i...
# 581        Ok anyway no need to change with what you said
# 583     my ex-wife was not able to have kids. Do you w...
# 584     So how's scotland. Hope you are not over showi...
# 585     Tell them u have a headache and just want to u...
# 586     I dun thk i'll quit yet... Hmmm, can go jazz ?...
# 587     \Pete can you please ring meive hardly gotany ...
# 588                           Ya srsly better than yi tho
# 589                    I'm in a meeting, call me later at
# 593                              You still at grand prix?
# 594     I met you as a stranger and choose you as my f...
# 595                              I am great! How are you?
# 596                         Gud mrng dear have a nice day
# 598     Will do. Was exhausted on train this morning. ...
# 599                I'm going out to buy mum's present ar.
# 600     Mind blastin.. No more Tsunamis will occur fro...
# 601     If u sending her home first it's ok lor. I'm n...
# 602                Speaking of does he have any cash yet?
# 603                Be happy there. I will come after noon
# 604                                Meet after lunch la...
# 605                             TaKe CaRE n gET WeLL sOOn
# 607     what I meant to say is cant wait to see u agai...
# 608                                   Neva mind it's ok..
# 609     It's fine, imma get a drink or somethin. Want ...
# 611     Its a valentine game. . . Send dis msg to all ...
# 612                                I have many dependents
# 613     THANX4 TODAY CER IT WAS NICE 2 CATCH UP BUT WE...
# 614     I called and said all to him:)then he have to ...
# 615     \Happy valentines day\" I know its early but i...
# 616     He like not v shock leh. Cos telling shuhui is...
# 617                             For my family happiness..
# 618     I come n pick Ì_ up... Come out immediately af...
# 619     Let there be snow. Let there be snow. This kin...
# 620                 Dear we got  &lt;#&gt;  dollars hi hi
# 621     Good words.... But words may leave u in dismay...
# 622     MAKE SURE ALEX KNOWS HIS BIRTHDAY IS OVER IN F...
# 623     sorry, no, have got few things to do. may be i...
# 624     Nah it's straight, if you can just bring bud o...
# 625     Haha good to hear, I'm officially paid and on ...
# 626     How many licks does it take to get to the cent...
# 627     Yup i thk they r e teacher said that will make...
# 630                   Please dont say like that. Hi hi hi
# 631                                              Thank u!
# 632     Oh that was a forwarded message. I thought you...
# 633     Got it. Seventeen pounds for seven hundred ml ...
# 635                                  Me n him so funny...
# 636     Sweetheart, hope you are not having that kind ...
# 637     When Ì_ login dat time... Dad fetching Ì_ home...
# 638                  What will we do in the shower, baby?
# 639     I had askd u a question some hours before. Its...
# 640     Well imma definitely need to restock before th...
# 641      said kiss, kiss, i can't do the sound effects...
# 642                  Probably gonna swing by in a wee bit
# 643                 Ya very nice. . .be ready on thursday
# 644     Allo! We have braved the buses and taken on th...
# 645     Watching cartoon, listening music &amp; at eve...
# 646     Do you mind if I ask what happened? You dont h...
# 648                   No prob. I will send to your email.
# 650     Thats cool! Sometimes slow and gentle. Sonetim...
# 651     I'm gonna say no. Sorry. I would but as normal...
# 652     Wait, do you know if wesleys in town? I bet sh...
# 653                            Fine i miss you very much.
# 654                          Did u got that persons story
# 655         Tell them the drug dealer's getting impatient
# 656     Sun cant come to earth but send luv as rays. c...
# 657                  You will be in the place of that man
# 658     It doesnt make sense to take it there unless i...
# 660     Under the sea, there lays a rock. In the rock,...
# 661                                Then mum's repent how?
# 662     Sorry me going home first... Daddy come fetch ...
# 663           Leave it de:-). Start Prepare for next:-)..
# 664     Yes baby! We can study all the positions of th...
# 665     En chikku nange bakra msg kalstiya..then had t...
# 666     Carlos'll be here in a minute if you still nee...
# 667                 This pay is  &lt;DECIMAL&gt;  lakhs:)
# 668                             Have a good evening! Ttyl
# 669                                 Did u receive my msg?
# 670                  Ho ho - big belly laugh! See ya tomo
# 673     Ditto. And you won't have to worry about me sa...
# 674        I've got  &lt;#&gt; , any way I could pick up?
# 675                    I dont knw pa, i just drink milk..
# 676     Maybe?! Say hi to  and find out if  got his ca...
# 677     Piggy, r u awake? I bet u're still sleeping. I...
# 678                              Cause I'm not freaky lol
# 679     Missed your call cause I was yelling at scrapp...
# 680        What is this 'hex' place you talk of? Explain!
# 681                        ÌÏ log off 4 wat. It's sdryb8i
# 682                                Is xy going 4 e lunch?
# 684     I wanted to ask Ì_ to wait 4 me to finish lect...
# 685                        Have you finished work yet? :)
# 686     Every King Was Once A Crying Baby And Every Gr...
# 862     Sorry, I guess whenever I can get a hold of my...
# 863     Did u find out what time the bus is at coz i n...
# 864         Dude ive been seeing a lotta corvettes lately
# 866     Same here, but I consider walls and bunkers an...
# 870     Well am officially in a philosophical hole, so...
# 871     Its going good...no problem..but still need li...
# 872                       I'll text you when I drop x off
# 873     Ugh its been a long day. I'm exhausted. Just w...
# 874     Talk With Yourself Atleast Once In A Day...!!!...
# 876          Are you in castor? You need to see something
# 881     see, i knew giving you a break a few times wou...
# 882     I love to give massages. I use lots of baby oi...
# 883                           Dude we should go sup again
# 884     Yoyyooo u know how to change permissions for a...
# 885                              Gibbs unsold.mike hussey
# 886     I like to talk pa but am not able to. I dont k...
# 887     Y dun cut too short leh. U dun like ah? She fa...
# 888                              You unbelievable faglord
# 889          Wife.how she knew the time of murder exactly
# 890                              Why do you ask princess?
# 891     I am great princess! What are you thinking abo...
# 892     Nutter. Cutter. Ctter. Cttergg. Cttargg. Ctarg...
# 893     It's ok i noe u're busy but i'm really too bor...
# 894     Doesn't g have class early tomorrow and thus s...
# 895     Superb Thought- \Be grateful that u dont have ...
# 896     Hope you are having a good week. Just checking in
# 897     I'm used to it. I just hope my agents don't dr...
# 898     Thursday night? Yeah, sure thing, we'll work i...
# 900     Probably money worries. Things are coming due ...
# 901           How is it possible to teach you. And where.
# 902     I wonder if your phone battery went dead ? I h...
# 903     Lovely smell on this bus and it ain't tobacco...
# 904     We're all getting worried over here, derek and...
# 905     Hey what's up charles sorry about the late reply.
# 907     I.ll give her once i have it. Plus she said gr...
# 908                       WHITE FUDGE OREOS ARE IN STORES
# 910     My love ! How come it took you so long to leav...
# 911                               I am sorry it hurt you.
# 912     Can't. I feel nauseous. I'm so pissed. I didn'...
# 913     Ok lor but not too early. Me still having proj...
# 914               Call me da, i am waiting for your call.
# 915     I could ask carlos if we could get more if any...
# 916     Was actually about to send you a reminder toda...
# 917     When people see my msgs, They think Iam addict...
# 918     Hey you gave them your photo when you register...
# 919                 Dont talk to him ever ok its my word.
# 920                               When u wana see it then
# 921     On ma way to school. Can you pls send me ashle...
# 922     It shall be fine. I have avalarr now. Will hol...
# 923     She went to attend another two rounds today..b...
# 924     Actually i deleted my old website..now i m blo...
# 925          K, wait chikku..il send aftr  &lt;#&gt; mins
# 926     But I'm on a diet. And I ate 1 too many slices...
# 927                   K:)i will give my kvb acc details:)
# 928                               Oh all have to come ah?
# 930     I'm really sorry i won't b able 2 do this frid...
# 931     Congratulations ore mo owo re wa. Enjoy it and...
# 932                    So do you have samus shoulders yet
# 933     What time you think you'll have it? Need to kn...
# 935                            Then dun wear jeans lor...
# 936       Since when, which side, any fever, any vomitin.
# 937                              K:)k.are you in college?
# 939     Better. Made up for Friday and stuffed myself ...
# 940     No we sell it all so we'll have tons if coins....
# 941     Theyre doing it to lots of places. Only hospit...
# 943     And also I've sorta blown him off a couple tim...
# 944     I sent my scores to sophas and i had to do sec...
# 945     I cant wait to see you! How were the photos we...
# 947     Hey i booked the kb on sat already... what oth...
# 948                              Chk in ur belovd ms dict
# 5383    Good day to You too.Pray for me.Remove the tee...
# 5384    How are you babes. Hope your doing ok. I had a...
# 5385    How do friends help us in problems? They give ...
# 5386                             I'm at work. Please call
# 5387    I will be gentle baby! Soon you will be taking...
# 5388             NOT MUCH NO FIGHTS. IT WAS A GOOD NITE!!
# 5389                 Ok.ok ok..then..whats ur todays plan
# 5390                           Nt joking seriously i told
# 5391                              Watching ajith film ah?
# 5392    Ooooooh I forgot to tell u I can get on yovill...
# 5393    All done, all handed in. Don't know if mega sh...
# 5394            I dont know exactly could you ask chechi.
# 5395    Dunno lei shd b driving lor cos i go sch 1 hr ...
# 5396             As in i want custom officer discount oh.
# 5397                        That's necessarily respectful
# 5398    Hi. Hope you had a good day. Have a better night.
# 5399        And he's apparently bffs with carly quick now
# 5400    HARD BUT TRUE: How much you show &amp;  expres...
# 5401    Babes I think I got ur brolly I left it in Eng...
# 5402    Hi babe its me thanks for coming even though i...
# 5403             So gd got free ice cream... I oso wan...
# 5404    Pls give her prometazine syrup. 5mls then  &lt...
# 5405                         So how many days since then?
# 5406                   Dear are you angry i was busy dear
# 5407    Yup he msg me: is tat yijue? Then i tot it's m...
# 5408                              ... Are you in the pub?
# 5409              There is a first time for everything :)
# 5410    Daddy, shu shu is looking 4 u... U wan me 2 te...
# 5411                 I ask if u meeting da ge tmr nite...
# 5412    Gr8. So how do you handle the victoria island ...
# 5413    Nite nite pocay wocay luv u more than n e thin...
# 5414                                           East coast
# 5415    You should get more chicken broth if you want ...
# 5416    My slave! I want you to take 2 or 3 pictures o...
# 5417             Nope. I just forgot. Will show next week
# 5418    So how are you really. What are you up to. How...
# 5419    I'm at bruce &amp; fowler now but I'm in my mo...
# 5420                I dont know oh. Hopefully this month.
# 5421             Hi elaine, is today's meeting confirmed?
# 5422              Ok k..sry i knw 2 siva..tats y i askd..
# 5423                               Sorry, I'll call later
# 5424    U horrible gal... U knew dat i was going out w...
# 5425             Otherwise had part time job na-tuition..
# 5426        Oh yeah! And my diet just flew out the window
# 5428                     You didnt complete your gist oh.
# 5429    Er yeah, i will b there at 15:26, sorry! Just ...
# 5430    If you can make it any time tonight or wheneve...
# 5431                   If I was I wasn't paying attention
# 5432                               Thanx a lot 4 ur help!
# 5433    You're gonna have to be way more specific than...
# 5434    Jesus armand really is trying to tell everybod...
# 5435                    I'm wif him now buying tix lar...
# 5436                           Mode men or have you left.
# 5437                         Am slow in using biola's fne
# 5438                 \What are youdoing later? Sar xxx\""
# 5439         Hey i've booked the 2 lessons on sun liao...
# 5440        Thank you. do you generally date the brothas?
# 5441    By the way, make sure u get train to worc fore...
# 5442    I thought i'd get him a watch, just cos thats ...
# 5444    Good morning. At the repair shop--the ONLY rea...
# 5445    And that's fine, I got enough bud to last most...
# 5446    I am back. Good journey! Let me know if you ne...
# 5447                So that takes away some money worries
# 5448    aight we can pick some up, you open before ton...
# 5450                              Sac needs to carry on:)
# 5451    Just sing HU. I think its also important to fi...
# 5452             What???? Hello wats talks email address?
# 5453               Except theres a chick with huge boobs.
# 5454         Im just wondering what your doing right now?
# 5455    Wishing you a beautiful day. Each moment revea...
# 5457                          Arun can u transfr me d amt
# 5458                               Sorry, I'll call later
# 5459    If you hear a loud scream in about &lt;#&gt; m...
# 5461    Ok i thk i got it. Then u wan me 2 come now or...
# 5463                                    U GOIN OUT 2NITE?
# 5464    I will treasure every moment we spend together...
# 5465    Shall I bring us a bottle of wine to keep us a...
# 5469                                              Ok lor.
# 5470                           I thought slide is enough.
# 5471                                                  Yup
# 5472    Well obviously not because all the people in m...
# 5473                  Ok lor Ì_ reaching then message me.
# 5474    Where's mummy's boy ? Is he being good or bad ...
# 5475    Dhoni have luck to win some big title.so we wi...
# 5476    Yes princess! I want to please you every night...
# 5477    What Today-sunday..sunday is holiday..so no wo...
# 5478                            No probably  &lt;#&gt; %.
# 5479    Really do hope the work doesnt get stressful. ...
# 5480                  Have you seen who's back at Holby?!
# 5481                      Shall call now dear having food
# 5483    So li hai... Me bored now da lecturer repeatin...
# 5484    , ,  and  picking them up from various points ...
# 5485    Also fuck you and your family for going to rho...
# 5486                    Ofcourse I also upload some songs
# 5488                              K. I will sent it again
# 5489          Oh thanks a lot..i already bought 2 eggs ..
# 5490                              K. I will sent it again
# 5491    U studying in sch or going home? Anyway i'll b...
# 5493    I think if he rule tamilnadu..then its very to...
# 5494    Cool, we shall go and see, have to go to tip a...
# 5495    Good afternoon, my love ... How goes your day ...
# 5496    Yes... I trust u to buy new stuff ASAP so I ca...
# 5498                   Why did I wake up on my own &gt;:(
# 5499        Now get step 2 outta the way. Congrats again.
# 5500    Love has one law; Make happy the person you lo...
# 5502                 Apo all other are mokka players only
# 5503    Perhaps * is much easy give your account ident...
# 5504             Wait . I will msg after  &lt;#&gt;  min.
# 5505    What i told before i tell. Stupid hear after i...
# 5506    God's love has no limit. God's grace has no me...
# 5507               I want to be inside you every night...
# 5508    Machan you go to gym tomorrow,  i wil come lat...
# 5509    Lol they were mad at first but then they woke ...
# 5510                             I went to project centre
# 5511              ItÛ÷s reassuring, in this crazy world.
# 5512                            Just making dinner, you ?
# 5513    Yes. Please leave at  &lt;#&gt; . So that at  ...
# 5514                    Oh... Okie lor...We go on sat...
# 5515    You are a great role model. You are giving so ...
# 5516    Ya, i'm referin to mei's ex wat... No ah, wait...
# 5517    Miles and smiles r made frm same letters but d...
# 5518    By the way, i've put a skip right outside the ...
# 5519    Can you pls send me that company name. In saib...
# 5520                     No. I dont want to hear anything
# 5521                  You are a big chic. Common. Declare
# 5522                  Thats cool. I want to please you...
# 5523                              Going to join tomorrow.
# 5525    I want to tell you how bad I feel that basical...
# 5527    Total disappointment, when I texted you was th...
# 5528    Its just the effect of irritation. Just ignore it
# 5529                            What about this one then.
# 5530    I think that tantrum's finished so yeah I'll b...
# 5531    Compliments to you. Was away from the system. ...
# 5532             happened here while you were adventuring
# 5533    Hey chief, can you give me a bell when you get...
# 5534                         Ok which your another number
# 5535    I know you are thinkin malaria. But relax, chi...
# 5536    Aiyah ok wat as long as got improve can alread...
# 5538    I can't believe how attached I am to seeing yo...
# 5539                           Just sleeping..and surfing
# 5541                                Yeah it's jus rite...
# 5542             Armand says get your ass over to epsilon
# 5543               U still havent got urself a jacket ah?
# 5544    I'm taking derek &amp; taylor to walmart, if I...
# 5545        Hi its in durban are you still on this number
# 5546           Ic. There are a lotta childporn cars then.
# 5548                   No, I was trying it all weekend ;V
# 5549    You know, wot people wear. T shirts, jumpers, ...
# 5550          Cool, what time you think you can get here?
# 5551    Wen did you get so spiritual and deep. That's ...
# 5552    Have a safe trip to Nigeria. Wish you happines...
# 5553                          Hahaha..use your brain dear
# 5554    Well keep in mind I've only got enough gas for...
# 5555    Yeh. Indians was nice. Tho it did kane me off ...
# 5556    Yes i have. So that's why u texted. Pshew...mi...
# 5557    No. I meant the calculation is the same. That ...
# 5558                               Sorry, I'll call later
# 5559    if you aren't here in the next  &lt;#&gt;  hou...
# 5560                    Anything lor. Juz both of us lor.
# 5561    Get me out of this dump heap. My mom decided t...
# 5562    Ok lor... Sony ericsson salesman... I ask shuh...
# 5563                                  Ard 6 like dat lor.
# 5564    Why don't you wait 'til at least wednesday to ...
# 5565                                         Huh y lei...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: text, dtype: object

# %%
img = WordCloud(background_color='white').generate(' '.join(spam_words))
# WordCloud() produces an image object, which can be displayed with plt.imshow
plt.imshow(img)
# axis aren't very useful for a word cloud
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
all_cloud = WordCloud(background_color='white', height=1000, width=400).generate(' '.join(all_words))
ham_cloud = WordCloud(background_color='white', height=600, width=800).generate(' '.join(ham_words))
spam_cloud = WordCloud(background_color='white', height=600, width=800).generate(' '.join(spam_words))

plt.figure(figsize=(10, 8))
axs = [plt.axes([0, 0, .5, 1]), plt.axes([.5, .5, .5, .5]), plt.axes([.5, 0, .5, .5])]

axs[0].imshow(all_cloud)
axs[1].imshow(ham_cloud)
axs[2].imshow(spam_cloud)

axs[0].set_title('All Words')
axs[1].set_title('Ham')
axs[2].set_title('Spam')

for ax in axs: ax.axis('off')

# %%
top_20_ham_bigrams = (pd.Series(nltk.ngrams(ham_words, 2))
                      .value_counts()
                      .head(20))

top_20_ham_bigrams.head()
# Out:
# (call, later)    52
# (ill, call)      48
# (let, know)      42
# (sorry, ill)     39
# (dont, know)     32
# dtype: int64

# %%
top_20_ham_bigrams.sort_values().plot.barh(color='pink', width=.9, figsize=(10, 6))

plt.title('20 Most frequently occuring ham bigrams')
plt.ylabel('Bigram')
plt.xlabel('# Occurances')

# make the labels pretty
ticks, _ = plt.yticks()
labels = top_20_ham_bigrams.reset_index()['index'].apply(lambda t: t[0] + ' ' + t[1])
_ = plt.yticks(ticks, labels)

# %%
# We can supply our own values to be used to determine how big the words (or
# phrases) should be through the `generate_from_frequencies` method. The
# supplied values must be in the form of a dictionary where the keys are the
# words (phrases), and the values are numbers that correspond to the sizes.
#
# We'll convert our series to a dictionary, and convert the tuples that make up
# the index into a single string that holds each phrase.


data = {k[0] + ' ' + k[1]: v for k, v in top_20_ham_bigrams.to_dict().items()}
img = WordCloud(background_color='white', width=800, height=400).generate_from_frequencies(data)
plt.figure(figsize=(8, 4))
plt.imshow(img)
plt.axis('off')
plt.show()
